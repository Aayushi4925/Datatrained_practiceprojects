# %% [markdown]
# # Census Income Project

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
d = pd.read_csv('census.csv')

# %%
df = pd.DataFrame(d)

# %%
df.head()
# Out:
#    Age          Workclass  Fnlwgt   Education  Education_num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         Marital_status          Occupation    Relationship    Race      Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    Capital_gain  Capital_loss  Hours_per_week  Native_country  Income
# 0             0             0              13   United-States   <=50K
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32560 non-null  int64
#  1   Workclass       32560 non-null  object
#  2   Fnlwgt          32560 non-null  int64
#  3   Education       32560 non-null  object
#  4   Education_num   32560 non-null  int64
#  5   Marital_status  32560 non-null  object
#  6   Occupation      32560 non-null  object
#  7   Relationship    32560 non-null  object
#  8   Race            32560 non-null  object
#  9   Sex             32560 non-null  object
#  10  Capital_gain    32560 non-null  int64
#  11  Capital_loss    32560 non-null  int64
#  12  Hours_per_week  32560 non-null  int64
#  13  Native_country  32560 non-null  object
#  14  Income          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %% [markdown]
# Total 15 columns :
#
# 1 Target Variable=Income
#
# 14 Independent variable

# %% [markdown]
# 6 int type features and 9 categorical features

# %%
df.describe()
# Out:
#                 Age        Fnlwgt  Education_num  Capital_gain  Capital_loss  \
# count  32560.000000  3.256000e+04   32560.000000  32560.000000  32560.000000
# mean      38.581634  1.897818e+05      10.080590   1077.615172     87.306511
# std       13.640642  1.055498e+05       2.572709   7385.402999    402.966116
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178315e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783630e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370545e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        Hours_per_week
# count    32560.000000
# mean        40.437469
# std         12.347618
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# highest spreaded column: Capital_gain(minimum val = 0 , max val = 99999)
#
# Least spreaded column : Education_num
#
# Skewness is present in the columns

# %%
sns.heatmap(df.isnull(),cbar=False)

# %% [markdown]
# No null values in the dataset

# %%
df.isnull().sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %%
numerical_f = [i for i in df if df[i].dtypes!='O']

# %%
numerical_f
# Out:
# ['Age',
#  'Fnlwgt',
#  'Education_num',
#  'Capital_gain',
#  'Capital_loss',
#  'Hours_per_week']

# %%
categorical_f = [i for i in df if df[i].dtypes=='O']

# %%
categorical_f
# Out:
# ['Workclass',
#  'Education',
#  'Marital_status',
#  'Occupation',
#  'Relationship',
#  'Race',
#  'Sex',
#  'Native_country',
#  'Income']

# %%
df['Capital_gain'].value_counts()
# Out:
# 0        29849
# 15024      347
# 7688       284
# 7298       246
# 99999      159
#          ...
# 4931         1
# 1455         1
# 6097         1
# 22040        1
# 1111         1
# Name: Capital_gain, Length: 119, dtype: int64

# %% [markdown]
# frequent value in capital gain is 0 (29849 times out of 32560 )

# %%
per_zero =  (29849*100)/32560

# %%
per_zero
# Out:
# 91.67383292383292

# %% [markdown]
# 91% of values in capital gain is 0

# %%
df['Capital_loss'].value_counts()
# Out:
# 0       31041
# 1902      202
# 1977      168
# 1887      159
# 1848       51
#         ...
# 1411        1
# 1539        1
# 2472        1
# 1944        1
# 2201        1
# Name: Capital_loss, Length: 92, dtype: int64

# %% [markdown]
# Same as capital gain frequent value is 0

# %%
per_zero = (31041*100)/32560
per_zero
# Out:
# 95.33476658476658

# %% [markdown]
# 95% of values in capital loss is zero

# %% [markdown]
# # Univariate analysis

# %%
for i in numerical_f:
    print(i)
    df[i].hist()
    plt.show()
# Out:
# Age
# Fnlwgt
# Education_num
# Capital_gain
# Capital_loss
# Hours_per_week

# %% [markdown]
# Value of age is distributed between 20 to 90
#
# Most of the people is in the age of 35 to 45
#
# Fnlwt values lies between 20k to 40k
#
# Most of the people working hours(per week) is 35 to 40

# %%
for i in categorical_f:
    plt.figure(figsize=(18,10))
    print(i)
    sns.countplot(df[i])
    plt.show()
# Out:
# Workclass
# Education
# Marital_status
# Occupation
# Relationship
# Race
# Sex
# Native_country
# Income

# %% [markdown]
# In workclass : private is the most frequent category
#
# In education : HS-grad
#
# In marital status : married spouse
#
# In occupation : Prof.speciality ((also "?" category is also there))
#
# In Race :  white is in approx. 70 %

# %% [markdown]
# # Bi variate Analysis

# %%
for i in categorical_f:
    print(i)
    print(df[i].value_counts())
    print("------------------------------------")
# Out:
# Workclass
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1297
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: Workclass, dtype: int64
# ------------------------------------
# Education
#  HS-grad         10501
#  Some-college     7291
#  Bachelors        5354
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           333
#  1st-4th           168
#  Preschool          51
# Name: Education, dtype: int64
# ------------------------------------
# Marital_status
#  Married-civ-spouse       14976
#  Never-married            10682
#  Divorced                  4443
#  Separated                 1025
# ...

# %% [markdown]
# Occupation , native country , workclass have unknown category "?"

# %%
plt.figure(figsize=(14,8))
sns.countplot(df['Relationship'],hue=df['Income'])

# %% [markdown]
# Most frequenct relationship is husband in the dataset
#
# Also husband relationship has largest count of salary more than 50k

# %%
plt.figure(figsize=(14,8))
sns.countplot(df['Marital_status'],hue=df['Income'])

# %% [markdown]
# Married spouse has max count of salary more than 50k
#
# And Never married is the category having least number of people of salary more than 50k

# %%
plt.figure(figsize=(14,8))
sns.countplot(df['Race'],hue=df['Income'])

# %% [markdown]
# Most of the people are white : where(approx. 20k) income<50k
#
# and 7k people income>50k

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_en = LabelEncoder()

# %%
df['Income'] = label_en.fit_transform(df['Income'])

# %% [markdown]
# # Multivariate analysis

# %%
sns.heatmap(df.corr(),annot=True)

# %% [markdown]
# Target variable is strongly correlated with age,Education_num,Hours per week

# %%
sns.pairplot(df)

# %% [markdown]
# replacing ? with nan values

# %%
d_n = d_n.replace('?',np.nan)

# %% [markdown]
# Occupation , Workclass and nation have ? records

# %%
d_n['Occupation'] = np.where(d_n['Occupation'].isnull(),d_n['Occupation'].mode(),d_n['Occupation'])

# %%
d_n['Workclass'] = np.where(d_n['Workclass'].isnull(),d_n['Workclass'].mode(),d_n['Workclass'])

# %%
d_n['Native_country'] = np.where(d_n['Native_country'].isnull(),d_n['Native_country'].mode(),d_n['Native_country'])

# %%
for i in numerical_f:
    sns.boxplot(d_n[i])
    plt.show()

# %% [markdown]
# Each feature has outliers

# %%
for i in d_n.columns:
    d_n[i] = label_en.fit_transform(d_n[i].values.reshape(-1,1))

# %%
d_n.head()
# Out:
#    Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0   33          6    2925          9             12               2
# 1   21          4   14085         11              8               0
# 2   36          4   15335          1              6               2
# 3   11          4   19354          9             12               2
# 4   20          4   17699         12             13               2
#
#    Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# 0           4             0     4    1             0             0
# 1           6             1     4    1             0             0
# 2           6             0     2    1             0             0
# 3          10             5     2    0             0             0
# 4           4             5     4    0             0             0
#
#    Hours_per_week  Native_country  Income
# 0              12              39       0
# 1              39              39       0
# ...

# %%
from scipy.stats import zscore

# %%
z_score = zscore(d_n)

# %%
d_new = d_n[(z_score<3).all(axis=1)]

# %%
d_new.shape
# Out:
# (29380, 15)

# %%
d_n.shape
# Out:
# (32560, 15)

# %%
per_loss = (32560-29380)/32560*100

# %%
per_loss
# Out:
# 9.766584766584767

# %% [markdown]
# 9%  data loss after removing outliers, therefore not removing it
#
# And replacing the values

# %%
d_n['Fnlwgt'] = np.where(d_n['Fnlwgt']>400000,d_n['Fnlwgt'].median(),d_n['Fnlwgt'])

# %%
sns.boxplot(d_n['Fnlwgt'])

# %%
d_n['Education_num'] = np.where(d_n['Education_num']<4,d_n['Education_num'].median(),d_n['Education_num'])

# %%
sns.boxplot(d_n['Education_num'])

# %%
q3 = d_n.Hours_per_week.quantile(0.75)

# %%
q1 = d_n.Hours_per_week.quantile(0.25)

# %%
Iqr = q3-q1

# %%
print(Iqr,q1,q3)
# Out:
# 5.0 39.0 44.0

# %%
lower_lim  = q1 - 1.5*(Iqr)
upper_lim = q3 + 1.5*(Iqr)

# %%
d_n['Hours_per_week'] = np.where(d_n['Hours_per_week']<30 ,d_n['Hours_per_week'].median(),d_n['Hours_per_week'])

# %%
d_n['Hours_per_week'] = np.where(d_n['Hours_per_week']>55 ,d_n['Hours_per_week'].median(),d_n['Hours_per_week'])

# %%
d_n.drop('Hours_per_week',axis=1,inplace=True)

# %%
d_n['Age'] = np.where(d_n['Age']>80 ,d_n['Age'].median(),d_n['Age'])

# %%
d_n['Hours_per_week'] = data_['Hours_per_week']

# %% [markdown]
# Outliers are replaced with median
#
# Performing scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
data__n = pd.DataFrame(sc.fit_transform(d_n),columns=d_n.columns)

# %%
data__n.head()
# Out:
#         Age  Workclass    Fnlwgt  Education  Education_num  Marital_status  \
# 0  0.837497   1.463883 -1.252060  -0.335443       1.214434       -0.406183
# 1 -0.042559   0.090121  0.592985   0.181319      -0.602627       -1.734026
# 2  1.057511   0.090121  0.799643  -2.402489      -1.511157       -0.406183
# 3 -0.775939   0.090121  1.464090  -0.335443       1.214434       -0.406183
# 4 -0.115897   0.090121  1.190475   0.439700       1.668699       -0.406183
#
#    Occupation  Relationship      Race       Sex  Capital_gain  Capital_loss  \
# 0   -0.608434     -0.900177  0.393675  0.703087     -0.278997      -0.20418
# 1   -0.135480     -0.277810  0.393675  0.703087     -0.278997      -0.20418
# 2   -0.135480     -0.900177 -1.962583  0.703087     -0.278997      -0.20418
# 3    0.810427      2.211658 -1.962583 -1.422298     -0.278997      -0.20418
# 4   -0.608434      2.211658  0.393675 -1.422298     -0.278997      -0.20418
#
#    Native_country   Income  Hours_per_week
# ...

# %% [markdown]
# separating independent and target variable

# %%
x = data__n.drop('Income',axis=1)

# %%
y = data_['Income']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.33)

# %%
lr =  LogisticRegression()
lr.fit(x_train,y_train)
pred = lr.predict(x_test)
accuracy_score(pred,y_test)
# Out:
# 0.8211261051651931

# %% [markdown]
# Logistic is giving 82% accuracy
#
# Finding best random_state

# %%
for i in range(1,500):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.33,random_state=i)
    lr =  LogisticRegression()
    lr.fit(x_train,y_train)
    pred_test = lr.predict(x_test)
    pred_train = lr.predict(x_train)
    if(round(accuracy_score(pred_test,y_test)*100,1)==round(accuracy_score(pred_train,y_train)*100,1)):
        print('random state',i)
        print('test accuracy',accuracy_score(pred_test,y_test))
        print('train accuracy',accuracy_score(pred_train,y_train))
# Out:
# random state 7
# test accuracy 0.8221498371335505
# train accuracy 0.8223240889296356
# random state 10
# test accuracy 0.8225221033038622
# train accuracy 0.8231492092596837
# random state 14
# test accuracy 0.8228013029315961
# train accuracy 0.8230116892046757
# random state 18
# test accuracy 0.8226151698464402
# train accuracy 0.8226449690579877
# random state 39
# test accuracy 0.822987436016752
# train accuracy 0.8228741691496677
# random state 51
# test accuracy 0.8233597021870638
# train accuracy 0.8228741691496677
# random state 55
# test accuracy 0.8225221033038622
# train accuracy 0.8234700893880358
# random state 60
# test accuracy 0.8225221033038622
# train accuracy 0.8225074490029796
# random state 82
# test accuracy 0.8234527687296417
# train accuracy 0.8226449690579877
# random state 87
# test accuracy 0.8232666356444858
# train accuracy 0.8231033692413477
# random state 93
# test accuracy 0.8227082363890181
# train accuracy 0.8231950492780197
# random state 95
# ...

# %% [markdown]
# Not much difference in the accuracy score
#
# So taking, 7

# %%
 x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.33,random_state=7)

# %%
from sklearn.model_selection import cross_val_score

# %%
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
algo_list = [DecisionTreeClassifier, KNeighborsClassifier,SVC,LogisticRegression]

# %%
for i in algo_list:
    obj = i()
    obj.fit(x_train,y_train)
    pred = obj.predict(x_test)
    cross_score = cross_val_score(obj,x,y,cv=4)
    print('cross score',cross_score.mean())
    print(i,'accuracy_score',accuracy_score(y_test,pred))
    print('confusion_matrix',confusion_matrix(y_test,pred))
    print('classification_report',classification_report(y_test,pred))
    print('-------------------------------------------------------------')
# Out:
# cross score 0.8108722358722358
# <class 'sklearn.tree._classes.DecisionTreeClassifier'> accuracy_score 0.8110749185667753
# confusion_matrix [[7115 1039]
#  [ 991 1600]]
# classification_report               precision    recall  f1-score   support
#
#            0       0.88      0.87      0.88      8154
#            1       0.61      0.62      0.61      2591
#
#     accuracy                           0.81     10745
#    macro avg       0.74      0.75      0.74     10745
# weighted avg       0.81      0.81      0.81     10745
#
# -------------------------------------------------------------
# cross score 0.8333845208845208
# <class 'sklearn.neighbors._classification.KNeighborsClassifier'> accuracy_score 0.834434620753839
# confusion_matrix [[7346  808]
#  [ 971 1620]]
# classification_report               precision    recall  f1-score   support
#
#            0       0.88      0.90      0.89      8154
#            1       0.67      0.63      0.65      2591
#
# ...

# %% [markdown]
# SVC is giving best accuracy score and difference between cross_val and accuracy is also less

# %% [markdown]
# Ensemble technique

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
ran_obj = RandomForestClassifier(n_estimators=100)

# %%
ran_obj.fit(x_train,y_train)
pred_ran = ran_obj.predict(x_test)

# %%
print('accuracy_score',accuracy_score(y_test,pred_ran))
print('confusion_matrix',confusion_matrix(y_test,pred_ran))
print('classification_report',classification_report(y_test,pred_ran))
# Out:
# accuracy_score 0.8584457887389484
# confusion_matrix [[7617  537]
#  [ 984 1607]]
# classification_report               precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91      8154
#            1       0.75      0.62      0.68      2591
#
#     accuracy                           0.86     10745
#    macro avg       0.82      0.78      0.79     10745
# weighted avg       0.85      0.86      0.85     10745

# %% [markdown]
# Random forest is giving 85.8% accuracy

# %% [markdown]
# Hyper parametric tuning

# %%
para_rb = {
    'n_estimators':[100,200,500],
    'max_depth':[3,5,10,50],
    'bootstrap':[True,False]
}

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
ran_obj = RandomForestClassifier(random_state=42)

# %%
random_cv = RandomizedSearchCV(estimator=ran_obj,param_distributions=para_rb)

# %%
random_cv.fit(x_train,y_train)
# Out:
# RandomizedSearchCV(estimator=RandomForestClassifier(random_state=42),
#                    param_distributions={'bootstrap': [True, False],
#                                         'max_depth': [3, 5, 10, 50],
#                                         'n_estimators': [100, 200, 500]})

# %%
best_p = random_cv.best_params_
best_s = random_cv.best_score_

# %%
print('best parameter',best_p)
print('best score',best_s)
# Out:
# best parameter {'n_estimators': 200, 'max_depth': 10, 'bootstrap': True}
# best score 0.8572541829016732

# %%
random_forest_ob = RandomForestClassifier(n_estimators=200, max_depth=10, bootstrap=True)

# %%
random_forest_ob.fit(x_train,y_train)
pred_ran_obj = random_forest_ob.predict(x_test)

# %%
print('Accuracy_score',accuracy_score(y_test,pred_ran_obj))
# Out:
# Accuracy_score 0.857328990228013

# %%
print(classification_report(y_test,pred_ran_obj))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.96      0.91      8154
#            1       0.80      0.54      0.65      2591
#
#     accuracy                           0.86     10745
#    macro avg       0.84      0.75      0.78     10745
# weighted avg       0.85      0.86      0.85     10745

# %%
confusion_mt = confusion_matrix(y_test,pred_ran_obj)

# %%
sns.heatmap(confusion_mt,annot=True)

# %% [markdown]
# Conclusion:
#
# After hyperparametric tuning accuracy score is 85.7%
#
# Correct rejection is above 78%
#
# F1 score = 0.91

# %%
import pickle  #saving the model

# %%
_census = 'cen.pkl'

# %%
pickle.dump(random_forest_ob,open(_census,'wb'))
