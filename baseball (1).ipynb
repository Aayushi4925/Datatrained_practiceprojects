# %% [markdown]
# # Baseball Case Study

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
d = pd.read_csv('baseball.csv')

# %%
df = pd.DataFrame(d)

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# 30 rows are there in dataset
#
# ERA is of float datatype,other features are of int type
#
# 16  independent features
#
# 1 target variable(W)

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# No null values in the dataset

# %%
import seaborn as sns

# %%
for i in df.columns:
    sns.scatterplot(x=i,y='W',data=df)
    plt.show()

# %% [markdown]
# No any significant relation can be seen of any variable with target variable
#
# RA, ER,ERA are negatively correlated
#
# SV is positively related with target

# %%
import seaborn as sns
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %% [markdown]
# Highest correlation is with ERA(seen in scatter plot)
#
# Least correlation is with H

# %%
sns.scatterplot(x='ER',y='RA',data=df)

# %% [markdown]
# ER and RA are highly correlated with each other (both are negatively corr with target)

# %%
sns.scatterplot(x='ER',y='ERA',data=df)

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# Most of the features are less skewed (difference between mean and median is less)
#
# SO has highest std deviation (highest spread of data)
#
# ERA is least spreaded feature

# %%
for i in df.columns:
    sns.boxplot(df[i],data=df)
    plt.show()

# %% [markdown]
# Negligible number of outliers therfore no need to fix it

# %%
for i in df.columns:
    print(i,df[i].skew())
# Out:
# W 0.047088688953686085
# R 1.2007863569707353
# AB 0.18343655908507983
# H 0.6702537173217267
# 2B -0.23064991757259148
# 3B 0.129502450836424
# HR 0.5164407366297173
# BB 0.15849848440330838
# SO -0.1560654813644833
# SB 0.4798928679573835
# RA 0.04573397531336112
# ER 0.05870979570981254
# ERA 0.053331339494040286
# CG 0.7368452725826206
# SHO 0.5657904298216165
# SV 0.6575235461553925
# E 0.8901318267689016

# %% [markdown]
# Considering the thresold of +-0.5
#
# R,H,CG,SV,E are skewed

# %%
for i in df.columns:
    sns.distplot(df[i])
    plt.show()

# %%
from sklearn.preprocessing import power_transform

# %%
df1 = pd.DataFrame(power_transform(df),columns=df.columns)

# %%
df1.head()
# Out:
#           W    R   AB    H        2B        3B        HR        BB        SO  \
# 0  1.346947  0.0  0.0  0.0  1.477685  1.033103 -0.764626 -1.610915 -2.569896
# 1  0.218658  0.0  0.0  0.0  0.084269  1.203320 -0.158581 -0.502749  0.134913
# 2  0.025271  0.0  0.0  0.0  1.670782 -0.160270 -0.689676  1.128294 -0.901254
# 3 -0.465574  0.0  0.0  0.0 -0.848600 -0.360521 -0.879049 -1.181207 -0.189628
# 4 -0.665017  0.0  0.0  0.0  0.792183  1.616444 -0.329850 -0.206771  0.085459
#
#          SB        RA        ER       ERA        CG       SHO        SV  \
# 0  0.939708 -0.660331 -0.497425 -0.500893 -0.359844 -0.789579  1.546378
# 1 -0.539693  0.175465  0.257974  0.261806 -0.359844  0.251775  0.360444
# 2  0.211956 -0.674621 -0.746906 -0.636459  1.993513 -0.245393 -0.607594
# 3 -0.642564  0.189512  0.113575  0.060804  1.220103 -0.510759 -0.764453
# 4  0.079629  1.603228  1.582654  1.520959  1.220103  0.251775 -1.095010
#
#           E
# 0 -0.334953
# 1 -0.532211
# 2 -1.342331
# 3  0.678524
# ...

# %% [markdown]
# Need to manually remove the skewness
#
# As power transform turns all rows of R,AB,H to 0

# %%
df['R_new'] = np.cbrt(df['R_new'])

# %%
df['R_new'] .skew()
# Out:
# 0.7810542494011562

# %%
df['AB_new'] = df['AB']**3

# %%
df['AB_new'].skew()
# Out:
# 0.029897979480899402

# %%
df.drop('AB_new',axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E', 'R_new', 'AB_new1'],
#       dtype='object')

# %%
df.drop('AB_new1',axis=1,inplace=True)

# %%
df['AB_1'] = df['AB']**5

# %%
df['AB_1'].skew()
# Out:
# 0.2724038051049286

# %%
df['R_new'] = np.cbrt(df['R_new'])

# %%
df['R_new'] = np.cbrt(df['R_new'])

# %%
df['R_new'].skew()
# Out:
# 0.7482799045369174

# %%
df['H_new'] = np.cbrt(df['H'])

# %%
df['H_new'].skew()
# Out:
# 0.6425985968647794

# %%
df['H_new'] = np.cbrt(df['H'])

# %%
df['H_new'].skew()
# Out:
# 0.6425985968647794

# %%
df['H_new'] = np.cbrt(df['H_new'])

# %%
df['H_new'].skew()
# Out:
# 0.6332514681502946

# %%
df['HR_new'] = np.sqrt(d['HR'])

# %%
df['HR_new'].skew()
# Out:
# 0.26494806722056563

# %%
df_new = df1.drop(['AB','R','H','HR'],axis=1)

# %%
df_new.head()
# Out:
#           W        2B        3B        BB        SO        SB        RA  \
# 0  1.346947  1.477685  1.033103 -1.610915 -2.569896  0.939708 -0.660331
# 1  0.218658  0.084269  1.203320 -0.502749  0.134913 -0.539693  0.175465
# 2  0.025271  1.670782 -0.160270  1.128294 -0.901254  0.211956 -0.674621
# 3 -0.465574 -0.848600 -0.360521 -1.181207 -0.189628 -0.642564  0.189512
# 4 -0.665017  0.792183  1.616444 -0.206771  0.085459  0.079629  1.603228
#
#          ER       ERA        CG       SHO        SV         E
# 0 -0.497425 -0.500893 -0.359844 -0.789579  1.546378 -0.334953
# 1  0.257974  0.261806 -0.359844  0.251775  0.360444 -0.532211
# 2 -0.746906 -0.636459  1.993513 -0.245393 -0.607594 -1.342331
# 3  0.113575  0.060804  1.220103 -0.510759 -0.764453  0.678524
# 4  1.582654  1.520959  1.220103  0.251775 -1.095010 -0.532211

# %%
df_new['H']  = df['H_new']

# %%
df_new['R']  = df['R_new']

# %%
df_new['AB']  = df['AB_1']

# %%
df_new['HR']  = df['HR_new']

# %%
df_new['AB'] = df['AB_new']

# %% [markdown]
# Performed required transformations to remove the skewness in selective columns

# %%
df_new.head(3)
# Out:
#           W        2B        3B        BB        SO        SB        RA  \
# 0  1.346947  1.477685  1.033103 -1.610915 -2.569896  0.939708 -0.660331
# 1  0.218658  0.084269  1.203320 -0.502749  0.134913 -0.539693  0.175465
# 2  0.025271  1.670782 -0.160270  1.128294 -0.901254  0.211956 -0.674621
#
#          ER       ERA        CG       SHO        SV         E         H  \
# 0 -0.497425 -0.500893 -0.359844 -0.789579  1.546378 -0.334953  2.253214
# 1  0.257974  0.261806 -0.359844  0.251775  0.360444 -0.532211  2.227302
# 2 -0.746906 -0.636459  1.993513 -0.245393 -0.607594 -1.342331  2.235616
#
#           R         HR         AB
# 0  1.062867  11.789826  74.665923
# 1  1.062479  12.489996  73.939164
# 2  1.062090  11.874342  73.749576

# %% [markdown]
# #dataset after removing skewness

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
min_max = MinMaxScaler()
dataset = pd.DataFrame(min_max.fit_transform(df_new),columns=df_new.columns)

# %%
dataset.head(3)
# Out:
#           W        2B        3B        BB        SO        SB        RA  \
# 0  0.873497  0.870695  0.837197  0.048344  0.000000  0.748302  0.374328
# 1  0.560056  0.524750  0.884702  0.366090  0.506069  0.384456  0.559638
# 2  0.506332  0.918635  0.504141  0.833761  0.312203  0.569318  0.371160
#
#          ER       ERA        CG       SHO        SV         E         H  \
# 0  0.394298  0.385015  0.367955  0.310206  0.884038  0.420990  0.910699
# 1  0.556462  0.547191  0.367955  0.556845  0.623229  0.368213  0.137919
# 2  0.340740  0.356189  1.000000  0.439093  0.410339  0.151461  0.385859
#
#           R        HR        AB
# 0  0.529338  0.342122  0.722098
# 1  0.439999  0.475958  0.313180
# 2  0.350413  0.358277  0.206506

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor

# %%
x = dataset.drop('W',axis=1)
y = dataset['W']

# %%
for i in range(1,100):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.33,random_state=i)
    lr =  LinearRegression()
    lr.fit(x_train,y_train)
    pred = lr.predict(x_test)
    r_score = r2_score(y_test,pred)
    error = mean_squared_error(y_test,pred)
    print('random_state',i)
    print('R score',r_score,'Error',error)
    print('RMS error',np.sqrt(error))
# Out:
# random_state 1
# R score 0.4080268834933414 Error 0.05468208665227424
# RMS error 0.2338420121626442
# random_state 2
# R score -0.9557407349604197 Error 0.14185350733391414
# RMS error 0.37663444788536554
# random_state 3
# R score -0.09561857827398201 Error 0.0984549905945091
# RMS error 0.31377538239082603
# random_state 4
# R score 0.8228359968742753 Error 0.01801160415473706
# RMS error 0.1342073178136612
# random_state 5
# R score 0.44042442975636575 Error 0.030890818471266734
# RMS error 0.17575784042615775
# random_state 6
# R score 0.8421844443137396 Error 0.01432518417011367
# RMS error 0.11968786141507279
# random_state 7
# R score 0.5685205972270007 Error 0.03462468703544473
# RMS error 0.18607709970720399
# random_state 8
# R score 0.4385993616236177 Error 0.04838511634320306
# RMS error 0.21996617090635337
# random_state 9
# R score 0.8037624624828518 Error 0.011958919782545378
# RMS error 0.10935684607076677
# random_state 10
# ...

# %% [markdown]
# Model is performing best with random_state 6

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.33,random_state=6)

# %%
list_algo = [LinearRegression,SVR,DecisionTreeRegressor,KNeighborsRegressor]

# %%
for i in list_algo:
    obj = i()
    obj.fit(x_train,y_train)
    pred = obj.predict(x_test)
    print(i,'r2_score',r2_score(y_test,pred))
    print('mean squared error',mean_squared_error(y_test,pred))
    print('rms',np.sqrt(mean_squared_error(y_test,pred)))
    print('---------')
# Out:
# <class 'sklearn.linear_model._base.LinearRegression'> r2_score 0.8421844443137396
# mean squared error 0.01432518417011367
# rms 0.11968786141507279
# ---------
# <class 'sklearn.svm._classes.SVR'> r2_score 0.4956986353641011
# mean squared error 0.04577628545066074
# rms 0.21395393301049817
# ---------
# <class 'sklearn.tree._classes.DecisionTreeRegressor'> r2_score 0.23595218245443006
# mean squared error 0.06935390908404977
# rms 0.2633513035548709
# ---------
# <class 'sklearn.neighbors._regression.KNeighborsRegressor'> r2_score 0.4477132319701872
# mean squared error 0.050132001451569895
# rms 0.2239017674150204
# ---------

# %% [markdown]
# Linear Regression is giving best r2_score of 0.84

# %%
from sklearn.model_selection import cross_val_score

# %%
for i in list_algo:
    obj = i()
    obj.fit(x_train,y_train)
    pred = obj.predict(x_test)
    cross_score = cross_val_score(obj,x,y,cv=7)
    print('cross score',cross_score.mean())
    print(i,'r2_score',r2_score(y_test,pred))
    print('mean squared error',mean_squared_error(y_test,pred))
    print('rms',np.sqrt(mean_squared_error(y_test,pred)))
    print('-------------------------------------------------------------')
# Out:
# cross score 0.33438402451283405
# <class 'sklearn.linear_model._base.LinearRegression'> r2_score 0.8421844443137396
# mean squared error 0.01432518417011367
# rms 0.11968786141507279
# -------------------------------------------------------------
# cross score 0.040341521476724394
# <class 'sklearn.svm._classes.SVR'> r2_score 0.4956986353641011
# mean squared error 0.04577628545066074
# rms 0.21395393301049817
# -------------------------------------------------------------
# cross score -1.3734302825509042
# <class 'sklearn.tree._classes.DecisionTreeRegressor'> r2_score 0.5929192503848435
# mean squared error 0.03695140624754487
# rms 0.1922274856713911
# -------------------------------------------------------------
# cross score -0.062100384235802046
# <class 'sklearn.neighbors._regression.KNeighborsRegressor'> r2_score 0.4477132319701872
# mean squared error 0.050132001451569895
# rms 0.2239017674150204
# -------------------------------------------------------------

# %% [markdown]
# Least difference between cross_val score and r2score is given by linear regression

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr_ = RandomForestRegressor(n_estimators=100,random_state=42)

# %%
rfr_.fit(x_train,y_train)
predict = rfr_.predict(x_test)
print(mean_squared_error(predict,y_test))
print(r2_score(y_test,predict))
# Out:
# 0.03879776195323893
# 0.572578593802116

# %% [markdown]
# Random forest is also not giving better result than linear model

# %%
from sklearn.ensemble import AdaBoostRegressor

# %%
lr_obj = LinearRegression()
abregressor = AdaBoostRegressor(n_estimators=100,base_estimator=lr_obj)

# %%
abregressor.fit(x_train,y_train)
predict = abregressor.predict(x_test)
r2_score(predict,y_test)
# Out:
# 0.7702668228022787

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
grad_regressor = GradientBoostingRegressor(n_estimators=100,random_state=0)

# %%
grad_regressor.fit(x_train,y_train)
predict = grad_regressor.predict(x_test)
print('r2_score',r2_score(predict,y_test))
print(mean_squared_error(predict,y_test))
# Out:
# r2_score -0.41887545501085954
# 0.03920810572676649

# %% [markdown]
# Ada boost is giving r2score of 77%(therefore trying hyper parametric tuning for adaboost)
#
# and Gradientboost is not working well

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
para = {
    'n_estimators':[100,300,500],
     'learning_rate':[0.01,0.1,0.5,1],
    'loss':['linear','square','exponential']
}

# %%
random_scv =  RandomizedSearchCV(AdaBoostRegressor(),param_distributions=para,cv=3)

# %%
random_scv.fit(x_train,y_train)
# Out:
# RandomizedSearchCV(cv=3, estimator=AdaBoostRegressor(),
#                    param_distributions={'learning_rate': [0.01, 0.1, 0.5, 1],
#                                         'loss': ['linear', 'square',
#                                                  'exponential'],
#                                         'n_estimators': [100, 300, 500]})

# %%
predict_scv =random_scv.predict(x_test)
print('r2_score',r2_score(predict_scv,y_test))
print(mean_squared_error(predict_scv,y_test))
# Out:
# r2_score -1.1675038653455059
# 0.03704837601776238

# %% [markdown]
# Hyper parametric is not working well here .
#
# Going with the linear model hyper parameters(as linear model was giving best result)

# %%
from sklearn.linear_model import Lasso,Ridge

# %%
list_lr = [Lasso,Ridge]

# %%
for i in list_lr:
    ob = i(alpha=0.001)
    ob.fit(x_train,y_train)
    predict = ob.predict(x_test)
    print(i,'r2_score',r2_score(predict,y_test))
    print(mean_squared_error(predict,y_test))
# Out:
# <class 'sklearn.linear_model._coordinate_descent.Lasso'> r2_score 0.868706261491424
# 0.007431055566806797
# <class 'sklearn.linear_model._ridge.Ridge'> r2_score 0.9049383012159748
# 0.009290055919889167

# %% [markdown]
# Lasso is giving 0.86 r2score
#
# Ridge is giving 0.90 r2score

# %%
ridge_ob = Ridge(alpha=0.001)
ridge_ob.fit(x_train,y_train)
predict = ridge_ob.predict(x_test)
print(i,'r2_score',r2_score(predict,y_test))
print('Mean squared error',mean_squared_error(predict,y_test))
# Out:
# <class 'sklearn.linear_model._ridge.Ridge'> r2_score 0.9049383012159748
# Mean squared error 0.009290055919889167

# %% [markdown]
# # Ridge Regression is giving 90% r2score

# %% [markdown]
# saving model

# %%
import pickle

# %%
baseball = 'base_ball.pkl'
pickle.dump(ridge_ob,open(baseball,'wb'))

# %% [markdown]
# conclusion

# %%
original_result = np.array(y_test)
pred_result = np.array(ridge_ob.predict(x_test))
df_comparison = pd.DataFrame({'original':pred_result,'predicted':pred_result})
df_comparison
# Out:
#    original  predicted
# 0  0.916502   0.916502
# 1  0.458555   0.458555
# 2  0.490914   0.490914
# 3  0.505353   0.505353
# 4  0.856975   0.856975
# 5 -0.102163  -0.102163
# 6  0.494751   0.494751
# 7  0.867770   0.867770
# 8  0.153976   0.153976
# 9  0.259426   0.259426
